# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Input, Concatenate
from keras.layers import Conv2D, Conv2DTranspose, Activation, MaxPooling2D, UpSampling2D
from keras.layers.advanced_activations import PReLU, LeakyReLU
from keras.models import Model
from keras.models import load_model
import tensorflow as tf
from keras import backend as K
from tensorflow.keras.optimizers import Adam
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline
import glob
from keras import losses
from sklearn.model_selection import train_test_split
from DataLoader import LoadData, Preprocess
from models import CreateCAE, CreateMMAE
from keras.callbacks import ModelCheckpoint
from keras.callbacks import EarlyStopping

#PyTorch lib
import torch
import torch.nn as nn
from torch.autograd import Variable
import torch.utils.data as Data
import torch.nn.functional as F
import torchvision
#Tools lib
import numpy as np
import cv2
import random
import time
import os
import argparse
#Metrics lib
from metrics import calc_psnr, calc_ssim
from keras.callbacks import ModelCheckpoint

# %%
def get_args():
    parser = argparse.ArgumentParser()
    parser.add_argument('-f')
    parser.add_argument("--architecture", type=str, default='CAE')
    parser.add_argument("--mode", type=str, default='rainstreaks')
    parser.add_argument("--data_dir", type=str, default='../Data')
    parser.add_argument("--traininghardness", type=str, default='heavy')
    parser.add_argument("--output_dir", type=str, default='./weights')
    parser.add_argument("--size", type=int, default=512)
    parser.add_argument("--displayfigures", type=bool, default=True)
    args = parser.parse_args()
    return args

# %%
args = get_args()
if args.traininghardness=='light':
    rainstreakDataset=['DID-MDN']
    raindropDataset=['RAINDROP1']
elif args.traininghardness=='meduim':
    rainstreakDataset=['DID-MDN','RAIN800','FU','RAIN100L']
    raindropDataset=['RAINDROP2']
elif  args.traininghardness=='heavy':
    print('WARNING: Training in heavy for rainstreaks/raindrop requires atleast 1TB of RAM')
    rainstreakDataset=['RAIN12600']
    raindropDataset=['RAINDROP1','RAINDROP2']
# Out:
# WARNING: Training in heavy for rainstreaks/raindrop requires atleast 1TB of RAM

# %%
if args.mode=='rainstreaks':
    rained_image, derained_image= LoadData(args.data_dir,rainstreakDataset)
else:
    rained_image, derained_image= LoadData(args.data_dir,raindropDataset)
rained_images, derained_images=Preprocess([rained_image,derained_image],[args.size,args.size])
if args.displayfigures==True:
    SampleRAINYimage=rained_images[600]*255
    SampleNORAINimage=derained_images[600]*255
    plt.imshow(SampleRAINYimage.astype(np.uint8))
    plt.imshow(SampleNORAINimage.astype(np.uint8))
X_train_norain, X_test_norain = train_test_split(derained_images, test_size=0.3, random_state=42)
X_train_rain, X_test_rain = train_test_split(rained_images, test_size=0.3, random_state=42)
# Out:
# Loading rainstreaks images from: ../Data/RAIN12600
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/1.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/10.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/100.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/101.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/102.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/103.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/104.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/105.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/106.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/107.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/108.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/109.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/11.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/110.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/111.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/112.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/113.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/114.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/115.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/116.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/117.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/118.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/119.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/12.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/120.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/121.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/122.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/123.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/124.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/125.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/126.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/127.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/128.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/129.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/13.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/130.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/131.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/132.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/133.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/134.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/135.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/136.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/137.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/138.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/139.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/14.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/140.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/141.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/142.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/143.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/144.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/145.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/146.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/147.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/148.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/149.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/15.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/150.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/151.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/152.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/153.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/154.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/155.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/156.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/157.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/158.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/159.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/16.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/160.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/161.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/162.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/163.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/164.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/165.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/166.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/167.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/168.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/169.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/17.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/170.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/171.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/172.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/173.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/174.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/175.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/176.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/177.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/178.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/179.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/18.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/180.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/181.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/182.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/183.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/184.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/185.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/186.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/187.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/188.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/189.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/19.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/190.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/191.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/192.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/193.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/194.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/195.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/196.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/197.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/198.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/199.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/2.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/20.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/200.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/201.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/202.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/203.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/204.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/205.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/206.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/207.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/208.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/209.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/21.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/210.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/211.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/212.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/213.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/214.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/215.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/216.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/217.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/218.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/219.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/22.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/220.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/221.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/222.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/223.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/224.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/225.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/226.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/227.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/228.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/229.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/23.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/230.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/231.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/232.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/233.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/234.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/235.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/236.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/237.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/238.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/239.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/24.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/240.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/241.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/242.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/243.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/244.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/245.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/246.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/247.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/248.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/249.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/25.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/250.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/251.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/252.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/253.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/254.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/255.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/256.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/257.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/258.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/259.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/26.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/260.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/261.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/262.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/263.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/264.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/265.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/266.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/267.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/268.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/269.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/27.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/270.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/271.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/272.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/273.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/274.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/275.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/276.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/277.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/278.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/279.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/28.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/280.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/281.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/282.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/283.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/284.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/285.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/286.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/287.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/288.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/289.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/29.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/290.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/291.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/292.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/293.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/294.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/295.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/296.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/297.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/298.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/299.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/3.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/30.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/300.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/301.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/302.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/303.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/304.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/305.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/306.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/307.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/308.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/309.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/31.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/310.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/311.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/312.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/313.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/314.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/315.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/316.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/317.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/318.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/319.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/32.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/320.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/321.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/322.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/323.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/324.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/325.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/326.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/327.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/328.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/329.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/33.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/330.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/331.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/332.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/333.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/334.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/335.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/336.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/337.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/338.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/339.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/34.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/340.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/341.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/342.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/343.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/344.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/345.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/346.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/347.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/348.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/349.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/35.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/350.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/351.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/352.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/353.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/354.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/355.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/356.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/357.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/358.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/359.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/36.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/360.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/361.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/362.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/363.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/364.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/365.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/366.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/367.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/368.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/369.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/37.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/370.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/371.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/372.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/373.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/374.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/375.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/376.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/377.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/378.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/379.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/38.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/380.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/381.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/382.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/383.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/384.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/385.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/386.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/387.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/388.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/389.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/39.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/390.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/391.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/392.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/393.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/394.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/395.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/396.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/397.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/398.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/399.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/4.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/40.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/400.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/401.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/402.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/403.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/404.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/405.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/406.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/407.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/408.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/409.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/41.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/410.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/411.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/412.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/413.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/414.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/415.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/416.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/417.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/418.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/419.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/42.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/420.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/421.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/422.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/423.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/424.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/425.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/426.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/427.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/428.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/429.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/43.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/430.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/431.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/432.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/433.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/434.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/435.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/436.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/437.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/438.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/439.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/44.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/440.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/441.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/442.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/443.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/444.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/445.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/446.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/447.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/448.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/449.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/45.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/450.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/451.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/452.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/453.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/454.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/455.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/456.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/457.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/458.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/459.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/46.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/460.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/461.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/462.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/463.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/464.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/465.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/466.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/467.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/468.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/469.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/47.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/470.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/471.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/472.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/473.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/474.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/475.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/476.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/477.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/478.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/479.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/48.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/480.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/481.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/482.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/483.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/484.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/485.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/486.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/487.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/488.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/489.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/49.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/490.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/491.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/492.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/493.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/494.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/495.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/496.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/497.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/498.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/499.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/5.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/50.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/500.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/501.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/502.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/503.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/504.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/505.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/506.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/507.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/508.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/509.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/51.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/510.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/511.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/512.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/513.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/514.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/515.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/516.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/517.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/518.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/519.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/52.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/520.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/521.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/522.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/523.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/524.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/525.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/526.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/527.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/528.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/529.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/53.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/530.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/531.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/532.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/533.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/534.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/535.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/536.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/537.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/538.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/539.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/54.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/540.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/541.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/542.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/543.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/544.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/545.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/546.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/547.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/548.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/549.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/55.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/550.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/551.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/552.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/553.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/554.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/555.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/556.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/557.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/558.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/559.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/56.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/560.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/561.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/562.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/563.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/564.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/565.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/566.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/567.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/568.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/569.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/57.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/570.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/571.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/572.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/573.jpg  and their rainy versions
# ...
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/753.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/754.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/755.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/756.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/757.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/758.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/759.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/76.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/760.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/761.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/762.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/763.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/764.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/765.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/766.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/767.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/768.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/769.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/77.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/770.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/771.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/772.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/773.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/774.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/775.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/776.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/777.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/778.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/779.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/78.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/780.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/781.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/782.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/783.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/784.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/785.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/786.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/787.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/788.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/789.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/79.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/790.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/791.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/792.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/793.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/794.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/795.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/796.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/797.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/798.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/799.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/8.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/80.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/800.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/801.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/802.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/803.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/804.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/805.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/806.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/807.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/808.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/809.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/81.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/810.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/811.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/812.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/813.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/814.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/815.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/816.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/817.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/818.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/819.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/82.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/820.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/821.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/822.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/823.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/824.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/825.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/826.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/827.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/828.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/829.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/83.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/830.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/831.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/832.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/833.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/834.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/835.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/836.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/837.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/838.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/839.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/84.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/840.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/841.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/842.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/843.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/844.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/845.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/846.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/847.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/848.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/849.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/85.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/850.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/851.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/852.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/853.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/854.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/855.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/856.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/857.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/858.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/859.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/86.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/860.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/861.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/862.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/863.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/864.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/865.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/866.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/867.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/868.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/869.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/87.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/870.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/871.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/872.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/873.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/874.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/875.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/876.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/877.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/878.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/879.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/88.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/880.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/881.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/882.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/883.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/884.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/885.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/886.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/887.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/888.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/889.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/89.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/890.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/891.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/892.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/893.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/894.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/895.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/896.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/897.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/898.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/899.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/9.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/90.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/900.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/91.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/92.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/93.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/94.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/95.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/96.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/97.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/98.jpg  and their rainy versions
# SEPERATE DATASET: READING ../Data/RAIN12600/ground_truth/99.jpg  and their rainy versions
# In total, we now have 12600 pairs of images
# The resultant array vector of one pairs is (12600, 512, 512, 3)

# %%
SampleRAINYimage=rained_images[0]*255
SampleNORAINimage=derained_images[0]*255

# %%
plt.imshow(SampleNORAINimage.astype(np.uint8))

# %%
plt.imshow(SampleRAINYimage.astype(np.uint8))

# %%
if args.architecture == 'MMAE':

    autoencoder=CreateMMAE([args.size,args.size,3])
    autoencoder.summary()
    autoencoder.compile(optimizer='adam', loss=losses.mean_squared_error,metrics = ['accuracy'])
    ES = EarlyStopping(monitor='val_loss', mode='min', verbose=1,patience=10)
    metric='val_loss'
    callbacks_list = [checkpoint,ES]
    checkpoint = ModelCheckpoint(filepath, monitor=metric, verbose=1, save_best_only=True, mode='min')
    Model.fit(autoencoder , [X_train_rain,X_train_norain], [X_train_norain,X_train_norain], validation_data=([X_test_rain,X_test_norain],[X_test_norain,X_test_norain]), epochs=150, shuffle=True, batch_size = 35)

elif args.architecture == 'CAE':
    autoencoder=CreateCAE([args.size,args.size,3])
    autoencoder.summary()
    autoencoder.compile(optimizer='adam', loss=losses.mean_squared_error,metrics = ['accuracy'])
    Model = load_model(args.output_dir+"/"+args.mode+"/SecondSaved.hdf5")

    filepath=args.output_dir+"/"+args.mode+"/Enhancer-{epoch:02d}-Accuracy-{accuracy:.2f}.hdf5"
    ES = EarlyStopping(monitor='val_accuracy', mode='max', verbose=1,patience=100)
    metric='val_accuracy'
    checkpoint = ModelCheckpoint(filepath, monitor=metric, verbose=1, save_best_only=True, mode='max')
    callbacks_list = [checkpoint,ES]
    History=Model.fit(X_train_rain, X_train_norain,  validation_data=(X_test_rain, X_test_norain), epochs=150,shuffle=True, callbacks=callbacks_list, batch_size = 35)
    #autoencoder.compile(optimizer='adam', loss='binary_crossentropy', metrics=['binary_crossentropy'])
    #autoencoder.save("./weights/raindrops/raindrop.hdf5")
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 512, 512, 3)]     0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 512, 512, 16)      784
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 256, 256, 16)      0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 256, 256, 32)      12832
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 128, 128, 32)      0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 128, 128, 64)      18496
# _________________________________________________________________
# conv2d_transpose_2 (Conv2DTr (None, 128, 128, 32)      18464
# _________________________________________________________________
# up_sampling2d_4 (UpSampling2 (None, 256, 256, 32)      0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 256, 256, 16)      12816
# _________________________________________________________________
# up_sampling2d_5 (UpSampling2 (None, 512, 512, 16)      0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 512, 512, 3)       435
# =================================================================
# Total params: 63,827
# Trainable params: 63,827
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/150
# 252/252 [==============================] - 2120s 8s/step - loss: 0.0030 - accuracy: 0.8350 - val_loss: 0.0029 - val_accuracy: 0.8415
#
# Epoch 00001: val_accuracy improved from -inf to 0.84149, saving model to ./weights/rainstreaks/Enhancer-01-Accuracy-0.84.hdf5
# Epoch 2/150
# 252/252 [==============================] - 2086s 8s/step - loss: 0.0029 - accuracy: 0.8373 - val_loss: 0.0028 - val_accuracy: 0.8521
#
# Epoch 00002: val_accuracy improved from 0.84149 to 0.85205, saving model to ./weights/rainstreaks/Enhancer-02-Accuracy-0.84.hdf5
# Epoch 3/150
# 252/252 [==============================] - 2066s 8s/step - loss: 0.0028 - accuracy: 0.8373 - val_loss: 0.0028 - val_accuracy: 0.8218
#
# Epoch 00003: val_accuracy did not improve from 0.85205
# Epoch 4/150
# 252/252 [==============================] - 2050s 8s/step - loss: 0.0028 - accuracy: 0.8338 - val_loss: 0.0030 - val_accuracy: 0.8437
#
# Epoch 00004: val_accuracy did not improve from 0.85205
# Epoch 5/150
# 252/252 [==============================] - 2057s 8s/step - loss: 0.0028 - accuracy: 0.8351 - val_loss: 0.0028 - val_accuracy: 0.8427
#
# Epoch 00005: val_accuracy did not improve from 0.85205
# Epoch 6/150
# 252/252 [==============================] - 2057s 8s/step - loss: 0.0028 - accuracy: 0.8377 - val_loss: 0.0028 - val_accuracy: 0.8356
#
# Epoch 00006: val_accuracy did not improve from 0.85205
# Epoch 7/150
# 252/252 [==============================] - 2057s 8s/step - loss: 0.0028 - accuracy: 0.8342 - val_loss: 0.0028 - val_accuracy: 0.8178
#
# Epoch 00007: val_accuracy did not improve from 0.85205
# Epoch 8/150
# 252/252 [==============================] - 2056s 8s/step - loss: 0.0028 - accuracy: 0.8361 - val_loss: 0.0028 - val_accuracy: 0.8451
#
# Epoch 00008: val_accuracy did not improve from 0.85205
# Epoch 9/150
# 252/252 [==============================] - 2053s 8s/step - loss: 0.0028 - accuracy: 0.8378 - val_loss: 0.0028 - val_accuracy: 0.8350
#
# Epoch 00009: val_accuracy did not improve from 0.85205
# Epoch 10/150
# 252/252 [==============================] - 2046s 8s/step - loss: 0.0027 - accuracy: 0.8380 - val_loss: 0.0027 - val_accuracy: 0.8391
#
# Epoch 00010: val_accuracy did not improve from 0.85205
# Epoch 11/150
# 252/252 [==============================] - 2053s 8s/step - loss: 0.0027 - accuracy: 0.8382 - val_loss: 0.0027 - val_accuracy: 0.8430
#
# Epoch 00011: val_accuracy did not improve from 0.85205
# Epoch 12/150
# 252/252 [==============================] - 2077s 8s/step - loss: 0.0027 - accuracy: 0.8354 - val_loss: 0.0027 - val_accuracy: 0.8332
#
# Epoch 00012: val_accuracy did not improve from 0.85205
# Epoch 13/150
# 252/252 [==============================] - 2086s 8s/step - loss: 0.0027 - accuracy: 0.8390 - val_loss: 0.0028 - val_accuracy: 0.8518
#
# Epoch 00013: val_accuracy did not improve from 0.85205
# Epoch 14/150
# 252/252 [==============================] - 2046s 8s/step - loss: 0.0027 - accuracy: 0.8407 - val_loss: 0.0028 - val_accuracy: 0.8324
#
# Epoch 00014: val_accuracy did not improve from 0.85205
# Epoch 15/150
# 252/252 [==============================] - 2049s 8s/step - loss: 0.0027 - accuracy: 0.8395 - val_loss: 0.0027 - val_accuracy: 0.8352
#
# Epoch 00015: val_accuracy did not improve from 0.85205
# Epoch 16/150
# 252/252 [==============================] - 2049s 8s/step - loss: 0.0027 - accuracy: 0.8367 - val_loss: 0.0028 - val_accuracy: 0.8189
#
# Epoch 00016: val_accuracy did not improve from 0.85205
# Epoch 17/150
# 252/252 [==============================] - 2046s 8s/step - loss: 0.0027 - accuracy: 0.8403 - val_loss: 0.0027 - val_accuracy: 0.8348
#
# Epoch 00017: val_accuracy did not improve from 0.85205
# Epoch 18/150
# 252/252 [==============================] - 2051s 8s/step - loss: 0.0027 - accuracy: 0.8392 - val_loss: 0.0028 - val_accuracy: 0.8020
#
# Epoch 00018: val_accuracy did not improve from 0.85205
# Epoch 19/150
# 252/252 [==============================] - 2056s 8s/step - loss: 0.0027 - accuracy: 0.8384 - val_loss: 0.0027 - val_accuracy: 0.8366
#
# Epoch 00019: val_accuracy did not improve from 0.85205
# Epoch 20/150
# 252/252 [==============================] - 2051s 8s/step - loss: 0.0027 - accuracy: 0.8390 - val_loss: 0.0027 - val_accuracy: 0.8411
#
# Epoch 00020: val_accuracy did not improve from 0.85205
# Epoch 21/150
# 252/252 [==============================] - 2052s 8s/step - loss: 0.0027 - accuracy: 0.8413 - val_loss: 0.0027 - val_accuracy: 0.8222
#
# Epoch 00021: val_accuracy did not improve from 0.85205
# Epoch 22/150
# 252/252 [==============================] - 2050s 8s/step - loss: 0.0027 - accuracy: 0.8377 - val_loss: 0.0028 - val_accuracy: 0.8550
#
# Epoch 00022: val_accuracy improved from 0.85205 to 0.85499, saving model to ./weights/rainstreaks/Enhancer-22-Accuracy-0.84.hdf5
# Epoch 23/150
# 252/252 [==============================] - 2044s 8s/step - loss: 0.0027 - accuracy: 0.8412 - val_loss: 0.0027 - val_accuracy: 0.8435
#
# Epoch 00023: val_accuracy did not improve from 0.85499
# Epoch 24/150
# 252/252 [==============================] - 2048s 8s/step - loss: 0.0027 - accuracy: 0.8416 - val_loss: 0.0027 - val_accuracy: 0.8515
#
# Epoch 00024: val_accuracy did not improve from 0.85499
# Epoch 25/150
# 252/252 [==============================] - 2051s 8s/step - loss: 0.0027 - accuracy: 0.8405 - val_loss: 0.0027 - val_accuracy: 0.8532
#
# Epoch 00025: val_accuracy did not improve from 0.85499
# Epoch 26/150
# 252/252 [==============================] - 2144s 9s/step - loss: 0.0027 - accuracy: 0.8412 - val_loss: 0.0027 - val_accuracy: 0.8609
#
# Epoch 00026: val_accuracy improved from 0.85499 to 0.86088, saving model to ./weights/rainstreaks/Enhancer-26-Accuracy-0.84.hdf5
# Epoch 27/150
# 252/252 [==============================] - 2178s 9s/step - loss: 0.0027 - accuracy: 0.8399 - val_loss: 0.0027 - val_accuracy: 0.8422
#
# Epoch 00027: val_accuracy did not improve from 0.86088
# Epoch 28/150
# 252/252 [==============================] - 2399s 10s/step - loss: 0.0027 - accuracy: 0.8417 - val_loss: 0.0027 - val_accuracy: 0.8363
#
# Epoch 00028: val_accuracy did not improve from 0.86088
# Epoch 29/150
# 252/252 [==============================] - 2467s 10s/step - loss: 0.0027 - accuracy: 0.8403 - val_loss: 0.0028 - val_accuracy: 0.8356
#
# Epoch 00029: val_accuracy did not improve from 0.86088
# Epoch 30/150
# 252/252 [==============================] - 2274s 9s/step - loss: 0.0027 - accuracy: 0.8407 - val_loss: 0.0027 - val_accuracy: 0.8590
#
# Epoch 00030: val_accuracy did not improve from 0.86088
# Epoch 31/150
# 252/252 [==============================] - 2190s 9s/step - loss: 0.0027 - accuracy: 0.8398 - val_loss: 0.0027 - val_accuracy: 0.8478
#
# Epoch 00031: val_accuracy did not improve from 0.86088
# Epoch 32/150
# 252/252 [==============================] - 2207s 9s/step - loss: 0.0027 - accuracy: 0.8402 - val_loss: 0.0027 - val_accuracy: 0.8293
#
# Epoch 00032: val_accuracy did not improve from 0.86088
# Epoch 33/150
# 252/252 [==============================] - 2251s 9s/step - loss: 0.0027 - accuracy: 0.8382 - val_loss: 0.0027 - val_accuracy: 0.8489
#
# Epoch 00033: val_accuracy did not improve from 0.86088
# Epoch 34/150
# 252/252 [==============================] - 2101s 8s/step - loss: 0.0026 - accuracy: 0.8434 - val_loss: 0.0027 - val_accuracy: 0.8420
#
# Epoch 00034: val_accuracy did not improve from 0.86088
# Epoch 35/150
# 252/252 [==============================] - 2157s 9s/step - loss: 0.0027 - accuracy: 0.8394 - val_loss: 0.0027 - val_accuracy: 0.8610
#
# Epoch 00035: val_accuracy improved from 0.86088 to 0.86097, saving model to ./weights/rainstreaks/Enhancer-35-Accuracy-0.84.hdf5
# Epoch 36/150
# 252/252 [==============================] - 2153s 9s/step - loss: 0.0026 - accuracy: 0.8419 - val_loss: 0.0027 - val_accuracy: 0.8398
#
# Epoch 00036: val_accuracy did not improve from 0.86097
# Epoch 37/150
# 252/252 [==============================] - 2072s 8s/step - loss: 0.0027 - accuracy: 0.8404 - val_loss: 0.0026 - val_accuracy: 0.8451
#
# Epoch 00037: val_accuracy did not improve from 0.86097
# Epoch 38/150
# 252/252 [==============================] - 2074s 8s/step - loss: 0.0027 - accuracy: 0.8430 - val_loss: 0.0027 - val_accuracy: 0.8588
#
# Epoch 00038: val_accuracy did not improve from 0.86097
# Epoch 39/150
# 252/252 [==============================] - 2050s 8s/step - loss: 0.0026 - accuracy: 0.8445 - val_loss: 0.0027 - val_accuracy: 0.8359
#
# Epoch 00039: val_accuracy did not improve from 0.86097
# Epoch 40/150
# 252/252 [==============================] - 2049s 8s/step - loss: 0.0026 - accuracy: 0.8443 - val_loss: 0.0026 - val_accuracy: 0.8394
#
# Epoch 00040: val_accuracy did not improve from 0.86097
# Epoch 41/150
# 252/252 [==============================] - 2044s 8s/step - loss: 0.0026 - accuracy: 0.8432 - val_loss: 0.0026 - val_accuracy: 0.8443
#
# Epoch 00041: val_accuracy did not improve from 0.86097
# Epoch 42/150
# 252/252 [==============================] - 2050s 8s/step - loss: 0.0026 - accuracy: 0.8438 - val_loss: 0.0027 - val_accuracy: 0.8441
#
# Epoch 00042: val_accuracy did not improve from 0.86097
# Epoch 43/150
# 252/252 [==============================] - 2046s 8s/step - loss: 0.0026 - accuracy: 0.8423 - val_loss: 0.0026 - val_accuracy: 0.8587
#
# Epoch 00043: val_accuracy did not improve from 0.86097
# Epoch 44/150
# 252/252 [==============================] - 2055s 8s/step - loss: 0.0026 - accuracy: 0.8415 - val_loss: 0.0027 - val_accuracy: 0.8140
#
# Epoch 00044: val_accuracy did not improve from 0.86097
# Epoch 45/150
# 252/252 [==============================] - 2107s 8s/step - loss: 0.0026 - accuracy: 0.8394 - val_loss: 0.0026 - val_accuracy: 0.8584
#
# Epoch 00045: val_accuracy did not improve from 0.86097
# Epoch 46/150
# 252/252 [==============================] - 2109s 8s/step - loss: 0.0026 - accuracy: 0.8434 - val_loss: 0.0026 - val_accuracy: 0.8622
#
# Epoch 00046: val_accuracy improved from 0.86097 to 0.86224, saving model to ./weights/rainstreaks/Enhancer-46-Accuracy-0.84.hdf5
# Epoch 47/150
# 252/252 [==============================] - 2090s 8s/step - loss: 0.0026 - accuracy: 0.8443 - val_loss: 0.0026 - val_accuracy: 0.8476
#
# Epoch 00047: val_accuracy did not improve from 0.86224
# Epoch 48/150
# 252/252 [==============================] - 2055s 8s/step - loss: 0.0026 - accuracy: 0.8391 - val_loss: 0.0027 - val_accuracy: 0.8496
#
# Epoch 00048: val_accuracy did not improve from 0.86224
# Epoch 49/150
# 252/252 [==============================] - 2043s 8s/step - loss: 0.0026 - accuracy: 0.8441 - val_loss: 0.0026 - val_accuracy: 0.8406
#
# Epoch 00049: val_accuracy did not improve from 0.86224
# Epoch 50/150
# 252/252 [==============================] - 2042s 8s/step - loss: 0.0026 - accuracy: 0.8428 - val_loss: 0.0026 - val_accuracy: 0.8563
#
# Epoch 00050: val_accuracy did not improve from 0.86224
# Epoch 51/150
# 252/252 [==============================] - 2038s 8s/step - loss: 0.0026 - accuracy: 0.8438 - val_loss: 0.0027 - val_accuracy: 0.8474
#
# Epoch 00051: val_accuracy did not improve from 0.86224
# Epoch 52/150
# 252/252 [==============================] - 2045s 8s/step - loss: 0.0026 - accuracy: 0.8442 - val_loss: 0.0027 - val_accuracy: 0.8400
#
# Epoch 00052: val_accuracy did not improve from 0.86224
# Epoch 53/150
# 252/252 [==============================] - 2034s 8s/step - loss: 0.0026 - accuracy: 0.8443 - val_loss: 0.0026 - val_accuracy: 0.8457
#
# Epoch 00053: val_accuracy did not improve from 0.86224
# Epoch 54/150
# 252/252 [==============================] - 2044s 8s/step - loss: 0.0026 - accuracy: 0.8415 - val_loss: 0.0026 - val_accuracy: 0.8317
#
# Epoch 00054: val_accuracy did not improve from 0.86224
# Epoch 55/150
# 252/252 [==============================] - 2041s 8s/step - loss: 0.0026 - accuracy: 0.8423 - val_loss: 0.0026 - val_accuracy: 0.8385
#
# Epoch 00055: val_accuracy did not improve from 0.86224
# Epoch 56/150
# 252/252 [==============================] - 2045s 8s/step - loss: 0.0026 - accuracy: 0.8419 - val_loss: 0.0026 - val_accuracy: 0.8604
#
# Epoch 00056: val_accuracy did not improve from 0.86224
# Epoch 57/150
# 252/252 [==============================] - 2040s 8s/step - loss: 0.0026 - accuracy: 0.8334 - val_loss: 0.0026 - val_accuracy: 0.8358
#
# Epoch 00057: val_accuracy did not improve from 0.86224
# Epoch 58/150
# 252/252 [==============================] - 2044s 8s/step - loss: 0.0026 - accuracy: 0.8420 - val_loss: 0.0026 - val_accuracy: 0.8470
#
# Epoch 00058: val_accuracy did not improve from 0.86224
# Epoch 59/150
# 252/252 [==============================] - 2046s 8s/step - loss: 0.0026 - accuracy: 0.8450 - val_loss: 0.0026 - val_accuracy: 0.8466
#
# Epoch 00059: val_accuracy did not improve from 0.86224
# Epoch 60/150
# 252/252 [==============================] - 2044s 8s/step - loss: 0.0026 - accuracy: 0.8430 - val_loss: 0.0026 - val_accuracy: 0.8607
#
# Epoch 00060: val_accuracy did not improve from 0.86224
# Epoch 61/150
# 252/252 [==============================] - 2039s 8s/step - loss: 0.0026 - accuracy: 0.8412 - val_loss: 0.0026 - val_accuracy: 0.8510
#
# Epoch 00061: val_accuracy did not improve from 0.86224
# Epoch 62/150
# 252/252 [==============================] - 2042s 8s/step - loss: 0.0026 - accuracy: 0.8415 - val_loss: 0.0026 - val_accuracy: 0.8302
#
# Epoch 00062: val_accuracy did not improve from 0.86224
# Epoch 63/150
# 252/252 [==============================] - 2044s 8s/step - loss: 0.0026 - accuracy: 0.8448 - val_loss: 0.0026 - val_accuracy: 0.8466
#
# Epoch 00063: val_accuracy did not improve from 0.86224
# Epoch 64/150
# 252/252 [==============================] - 2042s 8s/step - loss: 0.0026 - accuracy: 0.8426 - val_loss: 0.0026 - val_accuracy: 0.8455
#
# Epoch 00064: val_accuracy did not improve from 0.86224
# Epoch 65/150
# 252/252 [==============================] - 2040s 8s/step - loss: 0.0026 - accuracy: 0.8408 - val_loss: 0.0026 - val_accuracy: 0.8455
#
# Epoch 00065: val_accuracy did not improve from 0.86224
# Epoch 66/150
# 252/252 [==============================] - 2042s 8s/step - loss: 0.0026 - accuracy: 0.8442 - val_loss: 0.0026 - val_accuracy: 0.8596
#
# Epoch 00066: val_accuracy did not improve from 0.86224
# Epoch 67/150
# 252/252 [==============================] - 2150s 9s/step - loss: 0.0026 - accuracy: 0.8447 - val_loss: 0.0028 - val_accuracy: 0.8556
#
# Epoch 00067: val_accuracy did not improve from 0.86224
# Epoch 68/150
# 252/252 [==============================] - 2096s 8s/step - loss: 0.0026 - accuracy: 0.8441 - val_loss: 0.0026 - val_accuracy: 0.8523
#
# Epoch 00068: val_accuracy did not improve from 0.86224
# Epoch 69/150
# 252/252 [==============================] - 2069s 8s/step - loss: 0.0026 - accuracy: 0.8438 - val_loss: 0.0026 - val_accuracy: 0.8431
#
# Epoch 00069: val_accuracy did not improve from 0.86224
# Epoch 70/150
# 252/252 [==============================] - 2044s 8s/step - loss: 0.0026 - accuracy: 0.8430 - val_loss: 0.0026 - val_accuracy: 0.8589
#
# Epoch 00070: val_accuracy did not improve from 0.86224
# Epoch 71/150
# 252/252 [==============================] - 2037s 8s/step - loss: 0.0026 - accuracy: 0.8440 - val_loss: 0.0027 - val_accuracy: 0.8400
#
# Epoch 00071: val_accuracy did not improve from 0.86224
# Epoch 72/150
# 252/252 [==============================] - 2039s 8s/step - loss: 0.0026 - accuracy: 0.8412 - val_loss: 0.0026 - val_accuracy: 0.8411
#
# Epoch 00072: val_accuracy did not improve from 0.86224
# Epoch 73/150
# 252/252 [==============================] - 2047s 8s/step - loss: 0.0026 - accuracy: 0.8433 - val_loss: 0.0027 - val_accuracy: 0.8471
#
# Epoch 00073: val_accuracy did not improve from 0.86224
# Epoch 74/150
# 252/252 [==============================] - 2044s 8s/step - loss: 0.0026 - accuracy: 0.8441 - val_loss: 0.0026 - val_accuracy: 0.8595
#
# Epoch 00074: val_accuracy did not improve from 0.86224
# Epoch 75/150
# 252/252 [==============================] - 2047s 8s/step - loss: 0.0026 - accuracy: 0.8425 - val_loss: 0.0026 - val_accuracy: 0.8554
#
# Epoch 00075: val_accuracy did not improve from 0.86224
# Epoch 76/150
# 252/252 [==============================] - 2043s 8s/step - loss: 0.0026 - accuracy: 0.8426 - val_loss: 0.0027 - val_accuracy: 0.8420
#
# Epoch 00076: val_accuracy did not improve from 0.86224
# Epoch 77/150
# 252/252 [==============================] - 2045s 8s/step - loss: 0.0026 - accuracy: 0.8440 - val_loss: 0.0026 - val_accuracy: 0.8597
#
# Epoch 00077: val_accuracy did not improve from 0.86224
# Epoch 78/150
# 252/252 [==============================] - 2040s 8s/step - loss: 0.0026 - accuracy: 0.8442 - val_loss: 0.0026 - val_accuracy: 0.8332
#
# Epoch 00078: val_accuracy did not improve from 0.86224
# Epoch 79/150
# 252/252 [==============================] - 2038s 8s/step - loss: 0.0026 - accuracy: 0.8426 - val_loss: 0.0028 - val_accuracy: 0.8403
#
# Epoch 00079: val_accuracy did not improve from 0.86224
# Epoch 80/150
# 252/252 [==============================] - 2046s 8s/step - loss: 0.0026 - accuracy: 0.8442 - val_loss: 0.0026 - val_accuracy: 0.8498
#
# Epoch 00080: val_accuracy did not improve from 0.86224
# Epoch 81/150
# 252/252 [==============================] - 2042s 8s/step - loss: 0.0026 - accuracy: 0.8447 - val_loss: 0.0026 - val_accuracy: 0.8579
#
# Epoch 00081: val_accuracy did not improve from 0.86224
# Epoch 82/150
# 252/252 [==============================] - 2046s 8s/step - loss: 0.0026 - accuracy: 0.8429 - val_loss: 0.0027 - val_accuracy: 0.7590
#
# Epoch 00082: val_accuracy did not improve from 0.86224
# Epoch 83/150
# 252/252 [==============================] - 2043s 8s/step - loss: 0.0026 - accuracy: 0.8453 - val_loss: 0.0026 - val_accuracy: 0.8499
#
# Epoch 00083: val_accuracy did not improve from 0.86224
# Epoch 84/150
# 252/252 [==============================] - 2045s 8s/step - loss: 0.0026 - accuracy: 0.8440 - val_loss: 0.0027 - val_accuracy: 0.8616
#
# Epoch 00084: val_accuracy did not improve from 0.86224
# Epoch 85/150
# 252/252 [==============================] - 2043s 8s/step - loss: 0.0026 - accuracy: 0.8427 - val_loss: 0.0026 - val_accuracy: 0.8338
#
# Epoch 00085: val_accuracy did not improve from 0.86224
# Epoch 86/150
# 252/252 [==============================] - 2040s 8s/step - loss: 0.0026 - accuracy: 0.8416 - val_loss: 0.0026 - val_accuracy: 0.8412
#
# Epoch 00086: val_accuracy did not improve from 0.86224
# Epoch 87/150
# 252/252 [==============================] - 2041s 8s/step - loss: 0.0026 - accuracy: 0.8438 - val_loss: 0.0026 - val_accuracy: 0.8319
#
# Epoch 00087: val_accuracy did not improve from 0.86224
# Epoch 88/150
# 252/252 [==============================] - 2042s 8s/step - loss: 0.0026 - accuracy: 0.8431 - val_loss: 0.0026 - val_accuracy: 0.8543
#
# Epoch 00088: val_accuracy did not improve from 0.86224
# Epoch 89/150
# 252/252 [==============================] - 2041s 8s/step - loss: 0.0026 - accuracy: 0.8465 - val_loss: 0.0026 - val_accuracy: 0.8574
#
# Epoch 00089: val_accuracy did not improve from 0.86224
# Epoch 90/150
# 252/252 [==============================] - 2039s 8s/step - loss: 0.0026 - accuracy: 0.8433 - val_loss: 0.0026 - val_accuracy: 0.8508
#
# Epoch 00090: val_accuracy did not improve from 0.86224
# Epoch 91/150
# 252/252 [==============================] - 2046s 8s/step - loss: 0.0026 - accuracy: 0.8449 - val_loss: 0.0027 - val_accuracy: 0.8560
#
# Epoch 00091: val_accuracy did not improve from 0.86224
# Epoch 92/150
# 252/252 [==============================] - 2046s 8s/step - loss: 0.0026 - accuracy: 0.8444 - val_loss: 0.0026 - val_accuracy: 0.8602
#
# Epoch 00092: val_accuracy did not improve from 0.86224
# Epoch 93/150
# 252/252 [==============================] - 2044s 8s/step - loss: 0.0026 - accuracy: 0.8439 - val_loss: 0.0026 - val_accuracy: 0.8522
#
# Epoch 00093: val_accuracy did not improve from 0.86224
# Epoch 94/150
# 252/252 [==============================] - 2037s 8s/step - loss: 0.0026 - accuracy: 0.8468 - val_loss: 0.0026 - val_accuracy: 0.8539
#
# Epoch 00094: val_accuracy did not improve from 0.86224
# Epoch 95/150
# 252/252 [==============================] - 2043s 8s/step - loss: 0.0026 - accuracy: 0.8450 - val_loss: 0.0026 - val_accuracy: 0.8421
#
# Epoch 00095: val_accuracy did not improve from 0.86224
# Epoch 96/150
# 252/252 [==============================] - 2048s 8s/step - loss: 0.0026 - accuracy: 0.8448 - val_loss: 0.0026 - val_accuracy: 0.8459
#
# Epoch 00096: val_accuracy did not improve from 0.86224
# Epoch 97/150
# 252/252 [==============================] - 2045s 8s/step - loss: 0.0026 - accuracy: 0.8435 - val_loss: 0.0026 - val_accuracy: 0.8440
#
# Epoch 00097: val_accuracy did not improve from 0.86224
# Epoch 98/150
# 252/252 [==============================] - 2043s 8s/step - loss: 0.0026 - accuracy: 0.8420 - val_loss: 0.0026 - val_accuracy: 0.8336
#
# Epoch 00098: val_accuracy did not improve from 0.86224
# Epoch 99/150
# 252/252 [==============================] - 2047s 8s/step - loss: 0.0026 - accuracy: 0.8455 - val_loss: 0.0026 - val_accuracy: 0.8289
#
# Epoch 00099: val_accuracy did not improve from 0.86224
# Epoch 100/150
# 252/252 [==============================] - 2042s 8s/step - loss: 0.0026 - accuracy: 0.8415 - val_loss: 0.0027 - val_accuracy: 0.8078
#
# Epoch 00100: val_accuracy did not improve from 0.86224
# Epoch 101/150
# 252/252 [==============================] - 2047s 8s/step - loss: 0.0026 - accuracy: 0.8451 - val_loss: 0.0026 - val_accuracy: 0.8392
#
# Epoch 00101: val_accuracy did not improve from 0.86224
# Epoch 102/150
# 252/252 [==============================] - 2045s 8s/step - loss: 0.0026 - accuracy: 0.8457 - val_loss: 0.0026 - val_accuracy: 0.8407
#
# Epoch 00102: val_accuracy did not improve from 0.86224
# Epoch 103/150
# 252/252 [==============================] - 2044s 8s/step - loss: 0.0026 - accuracy: 0.8452 - val_loss: 0.0026 - val_accuracy: 0.8360
#
# Epoch 00103: val_accuracy did not improve from 0.86224
# Epoch 104/150
# 252/252 [==============================] - 2043s 8s/step - loss: 0.0026 - accuracy: 0.8443 - val_loss: 0.0026 - val_accuracy: 0.8461
#
# Epoch 00104: val_accuracy did not improve from 0.86224
# Epoch 105/150
# 252/252 [==============================] - 2042s 8s/step - loss: 0.0026 - accuracy: 0.8445 - val_loss: 0.0026 - val_accuracy: 0.8482
#
# Epoch 00105: val_accuracy did not improve from 0.86224
# Epoch 106/150
# 252/252 [==============================] - 2040s 8s/step - loss: 0.0026 - accuracy: 0.8429 - val_loss: 0.0027 - val_accuracy: 0.8551
#
# Epoch 00106: val_accuracy did not improve from 0.86224
# Epoch 107/150
# 252/252 [==============================] - 2042s 8s/step - loss: 0.0026 - accuracy: 0.8407 - val_loss: 0.0027 - val_accuracy: 0.8570
#
# Epoch 00107: val_accuracy did not improve from 0.86224
# Epoch 108/150
# 252/252 [==============================] - 2051s 8s/step - loss: 0.0026 - accuracy: 0.8442 - val_loss: 0.0026 - val_accuracy: 0.8533
#
# Epoch 00108: val_accuracy did not improve from 0.86224
# Epoch 109/150
# 252/252 [==============================] - 2043s 8s/step - loss: 0.0026 - accuracy: 0.8452 - val_loss: 0.0026 - val_accuracy: 0.8459
#
# Epoch 00109: val_accuracy did not improve from 0.86224
# Epoch 110/150
# 252/252 [==============================] - 2088s 8s/step - loss: 0.0026 - accuracy: 0.8463 - val_loss: 0.0025 - val_accuracy: 0.8549
#
# Epoch 00110: val_accuracy did not improve from 0.86224
# Epoch 111/150
# 252/252 [==============================] - 2081s 8s/step - loss: 0.0026 - accuracy: 0.8442 - val_loss: 0.0026 - val_accuracy: 0.8583
# Epoch 00111: val_accuracy did not improve from 0.86224
# Epoch 112/150
# 252/252 [==============================] - 2095s 8s/step - loss: 0.0026 - accuracy: 0.8457 - val_loss: 0.0026 - val_accuracy: 0.8481
#
# Epoch 00112: val_accuracy did not improve from 0.86224
# Epoch 113/150
# 252/252 [==============================] - 2100s 8s/step - loss: 0.0026 - accuracy: 0.8437 - val_loss: 0.0026 - val_accuracy: 0.8409
#
# Epoch 00113: val_accuracy did not improve from 0.86224
# Epoch 114/150
# 252/252 [==============================] - 2091s 8s/step - loss: 0.0026 - accuracy: 0.8440 - val_loss: 0.0026 - val_accuracy: 0.8504
#
# Epoch 00114: val_accuracy did not improve from 0.86224
# Epoch 115/150
# 252/252 [==============================] - 2183s 9s/step - loss: 0.0026 - accuracy: 0.8457 - val_loss: 0.0026 - val_accuracy: 0.8405
#
# Epoch 00115: val_accuracy did not improve from 0.86224
# Epoch 116/150
# 252/252 [==============================] - 2112s 8s/step - loss: 0.0026 - accuracy: 0.8426 - val_loss: 0.0026 - val_accuracy: 0.8335
#
# Epoch 00116: val_accuracy did not improve from 0.86224
# Epoch 117/150
# 252/252 [==============================] - 2085s 8s/step - loss: 0.0026 - accuracy: 0.8409 - val_loss: 0.0027 - val_accuracy: 0.8119
#
# Epoch 00117: val_accuracy did not improve from 0.86224
# Epoch 118/150
# 252/252 [==============================] - 2096s 8s/step - loss: 0.0026 - accuracy: 0.8407 - val_loss: 0.0026 - val_accuracy: 0.8504
#
# Epoch 00118: val_accuracy did not improve from 0.86224
# Epoch 119/150
# 252/252 [==============================] - 2095s 8s/step - loss: 0.0026 - accuracy: 0.8468 - val_loss: 0.0025 - val_accuracy: 0.8563
#
# Epoch 00119: val_accuracy did not improve from 0.86224
# Epoch 120/150
# 252/252 [==============================] - 2101s 8s/step - loss: 0.0026 - accuracy: 0.8457 - val_loss: 0.0026 - val_accuracy: 0.8348
#
# Epoch 00120: val_accuracy did not improve from 0.86224
# Epoch 121/150
# 252/252 [==============================] - 2090s 8s/step - loss: 0.0026 - accuracy: 0.8461 - val_loss: 0.0025 - val_accuracy: 0.8573
#
# Epoch 00121: val_accuracy did not improve from 0.86224
# Epoch 122/150
# 252/252 [==============================] - 2090s 8s/step - loss: 0.0026 - accuracy: 0.8431 - val_loss: 0.0026 - val_accuracy: 0.8512
#
# Epoch 00122: val_accuracy did not improve from 0.86224
# Epoch 123/150
# 252/252 [==============================] - 2092s 8s/step - loss: 0.0026 - accuracy: 0.8428 - val_loss: 0.0025 - val_accuracy: 0.8441
#
# Epoch 00123: val_accuracy did not improve from 0.86224
# Epoch 124/150
# 252/252 [==============================] - 2101s 8s/step - loss: 0.0026 - accuracy: 0.8446 - val_loss: 0.0025 - val_accuracy: 0.8449
#
# Epoch 00124: val_accuracy did not improve from 0.86224
# Epoch 125/150
# 252/252 [==============================] - 2098s 8s/step - loss: 0.0026 - accuracy: 0.8445 - val_loss: 0.0026 - val_accuracy: 0.8346
#
# Epoch 00125: val_accuracy did not improve from 0.86224
# Epoch 126/150
# 252/252 [==============================] - 2099s 8s/step - loss: 0.0026 - accuracy: 0.8433 - val_loss: 0.0026 - val_accuracy: 0.8447
#
# Epoch 00126: val_accuracy did not improve from 0.86224
# Epoch 127/150
# 252/252 [==============================] - 2094s 8s/step - loss: 0.0026 - accuracy: 0.8433 - val_loss: 0.0026 - val_accuracy: 0.8502
#
# Epoch 00127: val_accuracy did not improve from 0.86224
# Epoch 128/150
# 252/252 [==============================] - 2103s 8s/step - loss: 0.0026 - accuracy: 0.8462 - val_loss: 0.0027 - val_accuracy: 0.8573
#
# Epoch 00128: val_accuracy did not improve from 0.86224
# Epoch 129/150
# 252/252 [==============================] - 2110s 8s/step - loss: 0.0026 - accuracy: 0.8427 - val_loss: 0.0026 - val_accuracy: 0.8410
#
# Epoch 00129: val_accuracy did not improve from 0.86224
# Epoch 130/150
# 252/252 [==============================] - 2082s 8s/step - loss: 0.0026 - accuracy: 0.8461 - val_loss: 0.0026 - val_accuracy: 0.8566
#
# Epoch 00130: val_accuracy did not improve from 0.86224
# Epoch 131/150
# 252/252 [==============================] - 2072s 8s/step - loss: 0.0026 - accuracy: 0.8447 - val_loss: 0.0025 - val_accuracy: 0.8579
#
# Epoch 00131: val_accuracy did not improve from 0.86224
# Epoch 132/150
# 252/252 [==============================] - 2043s 8s/step - loss: 0.0026 - accuracy: 0.8462 - val_loss: 0.0026 - val_accuracy: 0.8251
#
# Epoch 00132: val_accuracy did not improve from 0.86224
# Epoch 133/150
# 252/252 [==============================] - 2034s 8s/step - loss: 0.0025 - accuracy: 0.8451 - val_loss: 0.0026 - val_accuracy: 0.8593
#
# Epoch 00133: val_accuracy did not improve from 0.86224
# Epoch 134/150
# 252/252 [==============================] - 2040s 8s/step - loss: 0.0026 - accuracy: 0.8437 - val_loss: 0.0026 - val_accuracy: 0.8170
#
# Epoch 00134: val_accuracy did not improve from 0.86224
# Epoch 135/150
# 252/252 [==============================] - 2040s 8s/step - loss: 0.0026 - accuracy: 0.8445 - val_loss: 0.0028 - val_accuracy: 0.8367
#
# Epoch 00135: val_accuracy did not improve from 0.86224
# Epoch 136/150
# 252/252 [==============================] - 2041s 8s/step - loss: 0.0026 - accuracy: 0.8425 - val_loss: 0.0026 - val_accuracy: 0.8399
#
# Epoch 00136: val_accuracy did not improve from 0.86224
# Epoch 137/150
# 252/252 [==============================] - 2034s 8s/step - loss: 0.0026 - accuracy: 0.8421 - val_loss: 0.0025 - val_accuracy: 0.8576
#
# Epoch 00137: val_accuracy did not improve from 0.86224
# Epoch 138/150
# 252/252 [==============================] - 2043s 8s/step - loss: 0.0025 - accuracy: 0.8458 - val_loss: 0.0025 - val_accuracy: 0.8415
#
# Epoch 00138: val_accuracy did not improve from 0.86224
# Epoch 139/150
# 252/252 [==============================] - 2045s 8s/step - loss: 0.0026 - accuracy: 0.8444 - val_loss: 0.0027 - val_accuracy: 0.7680
#
# Epoch 00139: val_accuracy did not improve from 0.86224
# Epoch 140/150
# 252/252 [==============================] - 2043s 8s/step - loss: 0.0026 - accuracy: 0.8424 - val_loss: 0.0026 - val_accuracy: 0.8325
#
# Epoch 00140: val_accuracy did not improve from 0.86224
# Epoch 141/150
# 252/252 [==============================] - 2043s 8s/step - loss: 0.0026 - accuracy: 0.8439 - val_loss: 0.0025 - val_accuracy: 0.8506
#
# Epoch 00141: val_accuracy did not improve from 0.86224
# Epoch 142/150
# 252/252 [==============================] - 2053s 8s/step - loss: 0.0026 - accuracy: 0.8434 - val_loss: 0.0026 - val_accuracy: 0.8420
#
# Epoch 00142: val_accuracy did not improve from 0.86224
# Epoch 143/150
# 252/252 [==============================] - 2076s 8s/step - loss: 0.0025 - accuracy: 0.8455 - val_loss: 0.0026 - val_accuracy: 0.8383
#
# Epoch 00143: val_accuracy did not improve from 0.86224
# Epoch 144/150
# 252/252 [==============================] - 2066s 8s/step - loss: 0.0026 - accuracy: 0.8443 - val_loss: 0.0026 - val_accuracy: 0.8465
#
# Epoch 00144: val_accuracy did not improve from 0.86224
# Epoch 145/150
# 252/252 [==============================] - 2099s 8s/step - loss: 0.0025 - accuracy: 0.8442 - val_loss: 0.0026 - val_accuracy: 0.8465
#
# Epoch 00145: val_accuracy did not improve from 0.86224
# Epoch 146/150
# 252/252 [==============================] - 2112s 8s/step - loss: 0.0026 - accuracy: 0.8417 - val_loss: 0.0026 - val_accuracy: 0.8576
#
# Epoch 00146: val_accuracy did not improve from 0.86224
# Epoch 00146: early stopping

# %%
if args.displayfigures==True:
    plt.plot(History.history['loss'])
    plt.plot(History.history['val_loss'])
    plt.plot(History.history['val_accuracy'])
    plt.plot(History.history['accuracy'])
    plt.title('model loss and accuracy')
    plt.ylabel('loss and accuracy')
    plt.xlabel('epoch')
    plt.legend(['accuracy','val_accuracy','loss',"val_loss"], loc='upper left')
    plt.show()

# %%
print(History.history)
# Out:
# {'loss': [0.005001252982765436, 0.0051021939143538475, 0.004959545098245144, 0.00499783456325531, 0.005091635510325432, 0.005037603434175253, 0.005037805996835232, 0.0050252992659807205, 0.005072665400803089, 0.005049790721386671, 0.00502812210470438, 0.004963771440088749, 0.004930312745273113, 0.004999713506549597, 0.005123618058860302], 'accuracy': [0.7788776159286499, 0.7759996652603149, 0.7769023776054382, 0.7823620438575745, 0.7702004313468933, 0.7674821615219116, 0.7732011079788208, 0.7702715992927551, 0.769943118095398, 0.7756390571594238, 0.7626421451568604, 0.780258297920227, 0.7754759788513184, 0.7706880569458008, 0.7687722444534302], 'val_loss': [0.005732681602239609, 0.005498465150594711, 0.0053552486933767796, 0.005797753110527992, 0.0054085347801446915, 0.00561516685411334, 0.0054061533883214, 0.005776542704552412, 0.005585256032645702, 0.005544137209653854, 0.005558578763157129, 0.005336782429367304, 0.005547640845179558, 0.005767039489001036, 0.005573816131800413], 'val_accuracy': [0.7795661091804504, 0.7620990872383118, 0.778749942779541, 0.7729560732841492, 0.782882809638977, 0.7803061008453369, 0.7768404483795166, 0.7785590291023254, 0.763499915599823, 0.7747688889503479, 0.7609104514122009, 0.7805080413818359, 0.7662844657897949, 0.7443122267723083, 0.7331314086914062]}

# %% [markdown]
# Train Multi Model Autoencoder
